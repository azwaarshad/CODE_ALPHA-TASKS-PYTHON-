# %% [markdown]
# # HANGMAN GAME

# %%
import random

def convert_to_lowercase(categories):
    for category in categories:
        categories[category] = [word.lower() for word in categories[category]]

def select_random_word(category):
    categories = {
        'animals': ['lion', 'tiger', 'elephant', 'giraffe', 'zebra',
    'panda', 'kangaroo', 'bear', 'wolf', 'fox',
    'rabbit', 'deer', 'cheetah', 'hippopotamus', 'rhino',
    'hippo', 'jaguar', 'leopard', 'bison', 'buffalo',
    'squirrel', 'koala', 'penguin', 'eagle', 'hawk',
    'owl', 'peacock', 'flamingo', 'dolphin', 'whale',
    'shark', 'octopus', 'seal', 'walrus', 'crocodile',
    'alligator', 'turtle', 'snake', 'lizard', 'frog',
    'toad', 'bat', 'rat', 'mouse', 'hamster',
    'gerbil', 'guinea pig', 'ferret', 'badger', 'otter'],
        
        'cities': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix',
    'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose',
    'Austin', 'Jacksonville', 'San Francisco', 'Columbus', 'Indianapolis',
    'Fort Worth', 'Charlotte', 'Seattle', 'Denver', 'El Paso',
    'Detroit', 'Boston', 'Memphis', 'Nashville', 'Baltimore',
    'Oklahoma City', 'Las Vegas', 'Louisville', 'Milwaukee', 'Albuquerque',
    'Tucson', 'Fresno', 'Sacramento', 'Kansas City', 'Mesa',
    'Virginia Beach', 'Atlanta', 'Colorado Springs', 'Omaha', 'Raleigh',
    'Miami', 'Cleveland', 'Tulsa', 'Oakland', 'Minneapolis',
    'Wichita', 'Arlington', 'Bakersfield', 'Tampa', 'Aurora',
    'Honolulu', 'Anaheim', 'Santa Ana', 'Corpus Christi', 'Riverside',
    'Lexington', 'St. Louis', 'Stockton', 'Cincinnati', 'St. Paul',
    'Pittsburgh', 'Greensboro', 'Anchorage', 'Plano', 'Orlando',
    'Irvine', 'Newark', 'Toledo', 'Durham', 'Chula Vista',
    'Fort Wayne', 'Jersey City', 'Buffalo', 'Madison', 'Lubbock',
    'Chandler', 'Glendale', 'Hialeah', 'Reno', 'Boise',
    'Des Moines', 'Tacoma', 'Aurora', 'Montgomery', 'Shreveport',
    'Augusta', 'Mobile', 'Little Rock', 'Huntington Beach', 'Columbia'],
        
        'colors': ['Red', 'Blue', 'Green', 'Yellow', 'Purple',
    'Orange', 'Pink', 'Brown', 'Black', 'White',
    'Gray', 'Cyan', 'Magenta', 'Maroon', 'Navy',
    'Olive', 'Teal', 'Lime', 'Indigo', 'Violet',
    'Gold', 'Silver', 'Bronze', 'Beige', 'Ivory',
    'Turquoise', 'Coral', 'Salmon', 'Lavender', 'Tan',
    'Mint', 'Peach', 'Plum', 'Chocolate', 'Rose',
    'Emerald', 'Ruby', 'Sapphire', 'Topaz', 'Amethyst',
    'Azure', 'Crimson', 'Burgundy', 'Aqua', 'Cerulean',
    'Periwinkle', 'Chartreuse', 'Khaki', 'Mauve', 'Wheat',
    'Sienna', 'Copper', 'Teal', 'Fuchsia', 'Celeste',
    'Lemon', 'Apricot', 'Cantaloupe', 'Papaya', 'Tangerine',
    'Sunset', 'Sunflower', 'Almond', 'Cinnamon', 'Brass',
    'Slate', 'Charcoal', 'Ash', 'Rosewood', 'Mahogany',
    'Jade', 'Seafoam', 'Daffodil', 'Pewter', 'Caramel',
    'Ginger', 'Lilac', 'Basil', 'Thistle', 'Ecru',
    'Platinum', 'Mulberry', 'Honeysuckle', 'Blush', 'Ocher'],
        
        'countries': ['United States', 'Canada', 'Mexico', 'Brazil', 'Argentina',
    'United Kingdom', 'France', 'Germany', 'Italy', 'Spain',
    'Australia', 'China', 'Japan', 'India', 'South Korea',
    'Russia', 'South Africa', 'Egypt', 'Nigeria', 'Kenya',
    'Saudi Arabia', 'Iran', 'Turkey', 'Saudi Arabia', 'Israel',
    'United Arab Emirates', 'Pakistan', 'Bangladesh', 'Thailand', 'Vietnam',
    'Indonesia', 'Malaysia', 'Singapore', 'Philippines', 'Myanmar',
    'New Zealand', 'Chile', 'Colombia', 'Peru', 'Venezuela',
    'Poland', 'Sweden', 'Norway', 'Denmark', 'Finland',
    'Greece', 'Portugal', 'Switzerland', 'Austria', 'Belgium',
    'Netherlands', 'Luxembourg', 'Ireland', 'Czech Republic', 'Hungary',
    'Slovakia', 'Ukraine', 'Belarus', 'Lithuania', 'Latvia',
    'Estonia', 'Romania', 'Bulgaria', 'Serbia', 'Croatia',
    'Slovenia', 'Montenegro', 'Bosnia and Herzegovina', 'North Macedonia', 'Albania',
    'Moldova', 'Georgia', 'Armenia', 'Azerbaijan', 'Kazakhstan',
    'Uzbekistan', 'Turkmenistan', 'Kyrgyzstan', 'Tajikistan', 'Afghanistan',
    'Sri Lanka', 'Nepal', 'Bhutan', 'Maldives', 'Brunei',
    'East Timor', 'Papua New Guinea', 'Fiji', 'Samoa', 'Tonga',
    'Solomon Islands', 'Vanuatu', 'Kiribati', 'Tuvalu', 'Nauru'],
        
        'fruits': [ 'Apple', 'Banana', 'Cherry', 'Date', 'Elderberry',
    'Fig', 'Grape', 'Honeydew', 'Kiwi', 'Lemon',
    'Mango', 'Nectarine', 'Orange', 'Papaya', 'Quince',
    'Raspberry', 'Strawberry', 'Tangerine', 'Uva Ursi', 'Vanilla Bean',
    'Watermelon', 'Ximenia', 'Yam Bean', 'Zucchini (Botanically a fruit)', 'Avocado',
    'Blackberry', 'Blueberry', 'Cantaloupe', 'Dragonfruit', 'Durian',
    'Gooseberry', 'Grapefruit', 'Guava', 'Jackfruit', 'Jambul',
    'Jujube', 'Kumquat', 'Lime', 'Lychee', 'Mandarin',
    'Mulberry', 'Olive', 'Passion Fruit', 'Peach', 'Pear',
    'Pineapple', 'Plum', 'Pomegranate', 'Rhubarb', 'Starfruit',
    'Coconut', 'Apricot', 'Cranberry', 'Raisin', 'Persimmon',
    'Prickly Pear', 'Longan', 'Salak', 'Soursop', 'Nance',
    'Satsuma', 'Dewberry', 'Elderflower', 'Feijoa', 'Finger Lime',
    'Granadilla', 'Kiwifruit', 'Lulo', 'Loquat', 'Mamey',
    'Mango Steen', 'Maracuja', 'Medlar', 'Mulberry', 'Noni',
    'Olallieberry', 'Pepino', 'Plantain', 'Salmonberry', 'Sapote',
    'Tamarind', 'Tomatillo', 'Yuzu', 'Ziziphus', 'Black Currant',
    'Carambola', 'Cucumber (Botanically a fruit)', 'Cupuacu', 'Tangelo', 'Custard Apple'],
        
        'movies': ['Bol', 'Khuda Kay Liye', 'Waar', 'Punjab Nahi Jaungi', 'Teefa in Trouble',
    'Jawani Phir Nahi Ani', 'Lahore Se Aagey', 'Actor in Law', 'Maalik', 'Wrong No.',
    'Kahaniyan', 'Chupan Chupai', 'Sultanat', 'Meri Ladli', 'Parchi',
    'Sarmad Khoosat', 'Bachana', 'Shanakht', 'Bashar Momin', 'Halla Gulla',
    'Gidh', 'Roti', 'Aangan', 'Chakori', 'Koi Tujh Sa',
    'Raja Sahib', 'Kya Yahi Pyaar Hai', 'Yeh Zindagi', 'Meherbani', 'Billo',
    'Kahani Koi', 'Paani', 'Zindagi Gulzar Hai', 'Dil Ruba', 'Aangan Terha',
    'Dastaan', 'Aangan', 'Meri Zindagi', 'Dunya', 'Jadoo Ka Shikanja',
    'Chup', 'Bachpan', 'Pataal', 'Kuch To Hai', 'Razia Sultan',
    'Hawaai', 'Kaaram', 'Laaj', 'Bachpan Ki Yaad', 'Aangan Ki Kahani', 'The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'Pulp Fiction', 'Forrest Gump',
    'Inception', 'Fight Club', 'The Matrix', 'The Lord of the Rings: The Return of the King', 'The Godfather Part II',
    'The Empire Strikes Back', 'The Good, the Bad and the Ugly', 'The Lord of the Rings: The Fellowship of the Ring', 'The Dark Knight Rises',
    'Interstellar', 'Gladiator', 'Braveheart', 'The Departed', 'Inglourious Basterds',
    'The Prestige', 'Django Unchained', 'The Lion King', 'Avatar', 'Titanic',
    'Schindler\'s List', 'The Usual Suspects', 'Psycho', 'Casablanca', 'Gone with the Wind',
    'Citizen Kane', 'The Wizard of Oz', 'Lawrence of Arabia', 'The Great Escape', 'Goodfellas',
    'A Beautiful Mind', 'Memento', 'Se7en', 'The Silence of the Lambs', '12 Angry Men',
    'The Intouchables', 'Amélie', 'The Green Mile', 'La La Land', 'The Revenant',
    'Mad Max: Fury Road', 'Whiplash', 'Her', 'The Big Lebowski', 'No Country for Old Men', 'Sholay', 'Dilwale Dulhania Le Jayenge', 'Kabhi Khushi Kabhie Gham', '3 Idiots', 'Lagaan',
    'Kabir Singh', 'Mughal-e-Azam', 'Pakeezah', 'Zindagi Na Milegi Dobara', 'Chakde! India',
    'Dangal', 'Bajrangi Bhaijaan', 'Barfi!', 'Piku', 'Queen',
    'Andhadhun', 'Gully Boy', 'Dil Chahta Hai', 'Taare Zameen Par', 'Hum',
    'Deewaar', 'Amar Akbar Anthony', 'Jab We Met', 'Don', 'Silsila',
    'Kuch Kuch Hota Hai', 'Kal Ho Naa Ho', 'Hum Aapke Hain Koun!', 'Maine Pyar Kiya', 'Satyam Shivam Sundaram',
    'Guide', 'Chupke Chupke', 'Shree 420', 'Pyaasa', 'Jewel Thief',
    'Mera Naam Joker', 'Satyajit Ray', 'Awaara', 'Naya Daur', 'Mr. India'],
        
        'sports': ['Soccer', 'Basketball', 'Tennis', 'Baseball', 'Hockey',
    'Golf', 'Rugby', 'Cricket', 'Volleyball', 'Table Tennis',
    'Badminton', 'Swimming', 'Track and Field', 'Boxing', 'Martial Arts',
    'Gymnastics', 'Diving', 'Skiing', 'Snowboarding', 'Surfing',
    'Cycling', 'Rowing', 'Wrestling', 'Fencing', 'Archery',
    'Sailing', 'Canoeing', 'Kayaking', 'Handball', 'Lacrosse',
    'Softball', 'Football', 'Ultimate Frisbee', 'Polo', 'Triathlon',
    'Darts', 'Snooker', 'Pool', 'Horse Racing', 'Speed Skating',
    'Figure Skating', 'Equestrian', 'Billiards', 'Ice Climbing', 'CrossFit',
    'Track Cycling', 'Synchronized Swimming', 'Rugby League', 'Rugby Union', 'Handball',
    'Beach Volleyball', 'Tug of War', 'Climbing', 'Hurdles', 'Korfball'],
        
        'vegetables': ['Carrot', 'Broccoli', 'Spinach', 'Pepper', 'Onion',
    'Tomato', 'Cucumber', 'Lettuce', 'Kale', 'Cauliflower',
    'Zucchini', 'Squash', 'Brussels Sprouts', 'Cabbage', 'Radish',
    'Beetroot', 'Turnip', 'Sweet Potato', 'Pumpkin', 'Corn',
    'Green Beans', 'Asparagus', 'Celery', 'Leek', 'Chard',
    'Artichoke', 'Fennel', 'Bok Choy', 'Endive', 'Arugula',
    'Jicama', 'Daikon', 'Yam', 'Okra', 'Mushroom',
    'Parsnip', 'Rutabaga', 'Chayote', 'Seaweed', 'Nopales',
    'Edamame', 'Oregano', 'Garlic', 'Shallot', 'Ginger',
    'Coriander', 'Dill', 'Chili Pepper', 'Hubbard Squash', 'Butternut Squash',
    'Taro', 'Yam Bean', 'Purslane', 'Celeriac', 'Kohlrabi',
    'Mizuna', 'Rapini', 'Samphire', 'Sorrel', 'Cress',
    'Cucumber', 'Coriander', 'Celosia', 'Dandelion Greens', 'Scallion',
    'Radicchio', 'Endive', 'Watercress', 'Hubbard Squash', 'Japanese Eggplant',
    'Snow Peas', 'Sweet Corn', 'Fennel', 'Cabbage', 'Collard Greens',
    'Bean Sprouts', 'Beet Greens', 'Corn Salad', 'Garlic Chives', 'Dandelion',
    'Chervil', 'Kombu', 'Maitake', 'Morel', 'Enoki',
    'Salsify', 'Sea Cucumber', 'Truffle', 'Beet']
    }
    
    if category not in categories:
        raise ValueError("Category not found.")
    return random.choice(categories[category])

def display_word(word, guessed_letters):
    return ' '.join([letter if letter in guessed_letters else '_' for letter in word])

def hangman():
    categories = {
        'animals': ['lion', 'tiger', 'elephant', 'giraffe', 'zebra',
    'panda', 'kangaroo', 'bear', 'wolf', 'fox',
    'rabbit', 'deer', 'cheetah', 'hippopotamus', 'rhino',
    'hippo', 'jaguar', 'leopard', 'bison', 'buffalo',
    'squirrel', 'koala', 'penguin', 'eagle', 'hawk',
    'owl', 'peacock', 'flamingo', 'dolphin', 'whale',
    'shark', 'octopus', 'seal', 'walrus', 'crocodile',
    'alligator', 'turtle', 'snake', 'lizard', 'frog',
    'toad', 'bat', 'rat', 'mouse', 'hamster',
    'gerbil', 'guinea pig', 'ferret', 'badger', 'otter'],
        
        'cities': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix',
    'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose',
    'Austin', 'Jacksonville', 'San Francisco', 'Columbus', 'Indianapolis',
    'Fort Worth', 'Charlotte', 'Seattle', 'Denver', 'El Paso',
    'Detroit', 'Boston', 'Memphis', 'Nashville', 'Baltimore',
    'Oklahoma City', 'Las Vegas', 'Louisville', 'Milwaukee', 'Albuquerque',
    'Tucson', 'Fresno', 'Sacramento', 'Kansas City', 'Mesa',
    'Virginia Beach', 'Atlanta', 'Colorado Springs', 'Omaha', 'Raleigh',
    'Miami', 'Cleveland', 'Tulsa', 'Oakland', 'Minneapolis',
    'Wichita', 'Arlington', 'Bakersfield', 'Tampa', 'Aurora',
    'Honolulu', 'Anaheim', 'Santa Ana', 'Corpus Christi', 'Riverside',
    'Lexington', 'St. Louis', 'Stockton', 'Cincinnati', 'St. Paul',
    'Pittsburgh', 'Greensboro', 'Anchorage', 'Plano', 'Orlando',
    'Irvine', 'Newark', 'Toledo', 'Durham', 'Chula Vista',
    'Fort Wayne', 'Jersey City', 'Buffalo', 'Madison', 'Lubbock',
    'Chandler', 'Glendale', 'Hialeah', 'Reno', 'Boise',
    'Des Moines', 'Tacoma', 'Aurora', 'Montgomery', 'Shreveport',
    'Augusta', 'Little Rock', 'Huntington Beach', 'Columbia'],
        
        'colors': ['Red', 'Blue', 'Green', 'Yellow', 'Purple',
    'Orange', 'Pink', 'Brown', 'Black', 'White',
    'Gray', 'Cyan', 'Magenta', 'Maroon', 'Navy',
    'Olive', 'Teal', 'Lime', 'Indigo', 'Violet',
    'Gold', 'Silver', 'Bronze', 'Beige', 'Ivory',
    'Turquoise', 'Coral', 'Salmon', 'Lavender', 'Tan',
    'Mint', 'Peach', 'Plum', 'Chocolate', 'Rose',
    'Emerald', 'Ruby', 'Sapphire', 'Topaz', 'Amethyst',
    'Azure', 'Crimson', 'Burgundy', 'Aqua', 'Cerulean',
    'Periwinkle', 'Chartreuse', 'Khaki', 'Mauve', 'Wheat',
    'Sienna', 'Copper', 'Teal', 'Fuchsia', 'Celeste',
    'Lemon', 'Apricot', 'Cantaloupe', 'Papaya', 'Tangerine',
    'Sunset', 'Sunflower', 'Almond', 'Cinnamon', 'Brass',
    'Slate', 'Charcoal', 'Ash', 'Rosewood', 'Mahogany',
    'Jade', 'Seafoam', 'Daffodil', 'Pewter', 'Caramel',
    'Ginger', 'Lilac', 'Basil', 'Thistle', 'Ecru',
    'Platinum', 'Mulberry', 'Honeysuckle', 'Blush', 'Ocher'],
        
        'countries': ['United States', 'Canada', 'Mexico', 'Brazil', 'Argentina',
    'United Kingdom', 'France', 'Germany', 'Italy', 'Spain',
    'Australia', 'China', 'Japan', 'India', 'South Korea',
    'Russia', 'South Africa', 'Egypt', 'Nigeria', 'Kenya',
    'Saudi Arabia', 'Iran', 'Turkey', 'Saudi Arabia', 'Israel',
    'United Arab Emirates', 'Pakistan', 'Bangladesh', 'Thailand', 'Vietnam',
    'Indonesia', 'Malaysia', 'Singapore', 'Philippines', 'Myanmar',
    'New Zealand', 'Chile', 'Colombia', 'Peru', 'Venezuela',
    'Poland', 'Sweden', 'Norway', 'Denmark', 'Finland',
    'Greece', 'Portugal', 'Switzerland', 'Austria', 'Belgium',
    'Netherlands', 'Luxembourg', 'Ireland', 'Czech Republic', 'Hungary',
    'Slovakia', 'Ukraine', 'Belarus', 'Lithuania', 'Latvia',
    'Estonia', 'Romania', 'Bulgaria', 'Serbia', 'Croatia',
    'Slovenia', 'Montenegro', 'Bosnia and Herzegovina', 'North Macedonia', 'Albania',
    'Moldova', 'Georgia', 'Armenia', 'Azerbaijan', 'Kazakhstan',
    'Uzbekistan', 'Turkmenistan', 'Kyrgyzstan', 'Tajikistan', 'Afghanistan',
    'Sri Lanka', 'Nepal', 'Bhutan', 'Maldives', 'Brunei',
    'East Timor', 'Papua New Guinea', 'Fiji', 'Samoa', 'Tonga',
    'Solomon Islands', 'Vanuatu', 'Kiribati', 'Tuvalu', 'Nauru'],
        
        'fruits': [ 'Apple', 'Banana', 'Cherry', 'Date', 'Elderberry',
    'Fig', 'Grape', 'Honeydew', 'Kiwi', 'Lemon',
    'Mango', 'Nectarine', 'Orange', 'Papaya', 'Quince',
    'Raspberry', 'Strawberry', 'Tangerine', 'Uva Ursi', 'Vanilla Bean',
    'Watermelon', 'Ximenia', 'Yam Bean', 'Zucchini (Botanically a fruit)', 'Avocado',
    'Blackberry', 'Blueberry', 'Cantaloupe', 'Dragonfruit', 'Durian',
    'Gooseberry', 'Grapefruit', 'Guava', 'Jackfruit', 'Jambul',
    'Jujube', 'Kumquat', 'Lime', 'Lychee', 'Mandarin',
    'Mulberry', 'Olive', 'Passion Fruit', 'Peach', 'Pear',
    'Pineapple', 'Plum', 'Pomegranate', 'Rhubarb', 'Starfruit',
    'Coconut', 'Apricot', 'Cranberry', 'Raisin', 'Persimmon',
    'Prickly Pear', 'Longan', 'Salak', 'Soursop', 'Nance',
    'Satsuma', 'Dewberry', 'Elderflower', 'Feijoa', 'Finger Lime',
    'Granadilla', 'Kiwifruit', 'Lulo', 'Loquat', 'Mamey',
    'Mango Steen', 'Maracuja', 'Medlar', 'Mulberry', 'Noni',
    'Olallieberry', 'Pepino', 'Plantain', 'Salmonberry', 'Sapote',
    'Tamarind', 'Tomatillo', 'Yuzu', 'Ziziphus', 'Black Currant',
    'Carambola', 'Cucumber (Botanically a fruit)', 'Cupuacu', 'Tangelo', 'Custard Apple'],
        
        'movies': ['Bol', 'Khuda Kay Liye', 'Waar', 'Punjab Nahi Jaungi', 'Teefa in Trouble',
    'Jawani Phir Nahi Ani', 'Lahore Se Aagey', 'Actor in Law', 'Maalik', 'Wrong No.',
    'Kahaniyan', 'Chupan Chupai', 'Sultanat', 'Meri Ladli', 'Parchi',
    'Sarmad Khoosat', 'Bachana', 'Shanakht', 'Bashar Momin', 'Halla Gulla',
    'Gidh', 'Roti', 'Aangan', 'Chakori', 'Koi Tujh Sa',
    'Raja Sahib', 'Kya Yahi Pyaar Hai', 'Yeh Zindagi', 'Meherbani', 'Billo',
    'Kahani Koi', 'Paani', 'Zindagi Gulzar Hai', 'Dil Ruba', 'Aangan Terha',
    'Dastaan', 'Aangan', 'Meri Zindagi', 'Dunya', 'Jadoo Ka Shikanja',
    'Chup', 'Bachpan', 'Pataal', 'Kuch To Hai', 'Razia Sultan',
    'Hawaai', 'Kaaram', 'Laaj', 'Bachpan Ki Yaad', 'Aangan Ki Kahani', 'The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'Pulp Fiction', 'Forrest Gump',
    'Inception', 'Fight Club', 'The Matrix', 'The Lord of the Rings: The Return of the King', 'The Godfather Part II',
    'The Empire Strikes Back', 'The Good, the Bad and the Ugly', 'The Lord of the Rings: The Fellowship of the Ring', 'The Dark Knight Rises',
    'Interstellar', 'Gladiator', 'Braveheart', 'The Departed', 'Inglourious Basterds',
    'The Prestige', 'Django Unchained', 'The Lion King', 'Avatar', 'Titanic',
    'Schindler\'s List', 'The Usual Suspects', 'Psycho', 'Casablanca', 'Gone with the Wind',
    'Citizen Kane', 'The Wizard of Oz', 'Lawrence of Arabia', 'The Great Escape', 'Goodfellas',
    'A Beautiful Mind', 'Memento', 'Se7en', 'The Silence of the Lambs', '12 Angry Men',
    'The Intouchables', 'Amélie', 'The Green Mile', 'La La Land', 'The Revenant',
    'Mad Max: Fury Road', 'Whiplash', 'Her', 'The Big Lebowski', 'No Country for Old Men', 'Sholay', 'Dilwale Dulhania Le Jayenge', 'Kabhi Khushi Kabhie Gham', '3 Idiots', 'Lagaan',
    'Kabir Singh', 'Mughal-e-Azam', 'Pakeezah', 'Zindagi Na Milegi Dobara', 'Chakde! India',
    'Dangal', 'Bajrangi Bhaijaan', 'Barfi!', 'Piku', 'Queen',
    'Andhadhun', 'Gully Boy', 'Dil Chahta Hai', 'Taare Zameen Par', 'Hum',
    'Deewaar', 'Amar Akbar Anthony', 'Jab We Met', 'Don', 'Silsila',
    'Kuch Kuch Hota Hai', 'Kal Ho Naa Ho', 'Hum Aapke Hain Koun!', 'Maine Pyar Kiya', 'Satyam Shivam Sundaram',
    'Guide', 'Chupke Chupke', 'Shree 420', 'Pyaasa', 'Jewel Thief',
    'Mera Naam Joker', 'Satyajit Ray', 'Awaara', 'Naya Daur', 'Mr. India'],
        
        'sports': ['Soccer', 'Basketball', 'Tennis', 'Baseball', 'Hockey',
    'Golf', 'Rugby', 'Cricket', 'Volleyball', 'Table Tennis',
    'Badminton', 'Swimming', 'Track and Field', 'Boxing', 'Martial Arts',
    'Gymnastics', 'Diving', 'Skiing', 'Snowboarding', 'Surfing',
    'Cycling', 'Rowing', 'Wrestling', 'Fencing', 'Archery',
    'Sailing', 'Canoeing', 'Kayaking', 'Handball', 'Lacrosse',
    'Softball', 'Football', 'Ultimate Frisbee', 'Polo', 'Triathlon',
    'Darts', 'Snooker', 'Pool', 'Horse Racing', 'Speed Skating',
    'Figure Skating', 'Equestrian', 'Billiards', 'Ice Climbing', 'CrossFit',
    'Track Cycling', 'Synchronized Swimming', 'Rugby League', 'Rugby Union', 'Handball',
    'Beach Volleyball', 'Tug of War', 'Climbing', 'Hurdles', 'Korfball'],
        
        'vegetables': ['Carrot', 'Broccoli', 'Spinach', 'Pepper', 'Onion',
    'Tomato', 'Cucumber', 'Lettuce', 'Kale', 'Cauliflower',
    'Zucchini', 'Squash', 'Brussels Sprouts', 'Cabbage', 'Radish',
    'Beetroot', 'Turnip', 'Sweet Potato', 'Pumpkin', 'Corn',
    'Green Beans', 'Asparagus', 'Celery', 'Leek', 'Chard',
    'Artichoke', 'Fennel', 'Bok Choy', 'Endive', 'Arugula',
    'Jicama', 'Daikon', 'Yam', 'Okra', 'Mushroom',
    'Parsnip', 'Rutabaga', 'Chayote', 'Seaweed', 'Nopales',
    'Edamame', 'Oregano', 'Garlic', 'Shallot', 'Ginger',
    'Coriander', 'Dill', 'Chili Pepper', 'Hubbard Squash', 'Butternut Squash',
    'Taro', 'Yam Bean', 'Purslane', 'Celeriac', 'Kohlrabi',
    'Mizuna', 'Rapini', 'Samphire', 'Sorrel', 'Cress',
    'Cucumber', 'Coriander', 'Celosia', 'Dandelion Greens', 'Scallion',
    'Radicchio', 'Endive', 'Watercress', 'Hubbard Squash', 'Japanese Eggplant',
    'Snow Peas', 'Sweet Corn', 'Fennel', 'Cabbage', 'Collard Greens',
    'Bean Sprouts', 'Beet Greens', 'Corn Salad', 'Garlic Chives', 'Dandelion',
    'Chervil', 'Kombu', 'Maitake', 'Morel', 'Enoki',
    'Salsify', 'Sea Cucumber', 'Truffle', 'Beet']
    }

    sentence = "Welcome to Hangman!"
    bold_sentence = "\033[1m" + sentence.upper() + "\033[0m"
    print(bold_sentence)

    print("Please choose a category:")
    
    for idx, category in enumerate(categories.keys(), start=1):
        print(f"{idx}. {category}")
    
    try:
        choice = int(input("Enter the number of the category: "))
        if choice < 1 or choice > len(categories):
            print("Invalid choice. Please choose a number from the list.")
            return
        category = list(categories.keys())[choice - 1]
    except ValueError:
        print("Invalid input. Please enter a number.")
        return

    word = select_random_word(category)
    guessed_letters = set()
    incorrect_guesses = 0
    max_incorrect_guesses = 6

    while incorrect_guesses < max_incorrect_guesses:
        current_display = display_word(word, guessed_letters)
        print(f"\nWord: {current_display}")
        print(f"Incorrect guesses: {incorrect_guesses}/{max_incorrect_guesses}")

        if '_' not in current_display:
            print(f"\nCongratulations! You guessed the word '{word}'!")
            break

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please guess a single letter.")
            continue

        if guess in guessed_letters:
            print("You have already guessed that letter.")
            continue

        guessed_letters.add(guess)

        if guess in word:
            print(f"Good guess! '{guess}' is in the word.")
        else:
            print(f"Sorry, '{guess}' is not in the word.")
            incorrect_guesses += 1

    if incorrect_guesses == max_incorrect_guesses:
        print(f"\nGame over! The word was '{word}'.")

if __name__ == "__main__":
    hangman()
# Out:
# WELCOME TO HANGMAN!
# Please choose a category:
# 1. animals
# 2. cities
# 3. colors
# 4. countries
# 5. fruits
# 6. movies
# 7. sports
# 8. vegetables
# Enter the number of the category: 3
#
# Word: _ _ _ _ _
# Incorrect guesses: 0/6
# Guess a letter: a
# Sorry, 'a' is not in the word.
#
# Word: _ _ _ _ _
# Incorrect guesses: 1/6
# Guess a letter: e
# Good guess! 'e' is in the word.
#
# Word: _ _ _ _ e
# Incorrect guesses: 1/6
# Guess a letter: c
# Sorry, 'c' is not in the word.
#
# Word: _ _ _ _ e
# Incorrect guesses: 2/6
# Guess a letter: h
# Sorry, 'h' is not in the word.
#
# Word: _ _ _ _ e
# Incorrect guesses: 3/6
# Guess a letter: i
# Good guess! 'i' is in the word.
#
# Word: _ _ i _ e
# Incorrect guesses: 3/6
# Guess a letter: l
# Good guess! 'l' is in the word.
#
# Word: _ l i _ e
# Incorrect guesses: 3/6
# Guess a letter: f
# Sorry, 'f' is not in the word.
#
# Word: _ l i _ e
# Incorrect guesses: 4/6
# Guess a letter: r
# Sorry, 'r' is not in the word.
#
# Word: _ l i _ e
# ...
